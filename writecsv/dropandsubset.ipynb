# %%
var.dropna(subset=["agent","company"])
# Out:
# Running cells with 'venv (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/pandas/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd

var = pd.read_csv(r"D:\hotel_bookings.csv")
var.info()
var.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
var.dropna(how="all")
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
var.dropna(inplace=True)

# %%
var.isna().sum()

# %%
var.info()
var.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 217 entries, 2392 to 116451
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           217 non-null    object
#  1   is_canceled                     217 non-null    int64
#  2   lead_time                       217 non-null    int64
#  3   arrival_date_year               217 non-null    int64
#  4   arrival_date_month              217 non-null    object
#  5   arrival_date_week_number        217 non-null    int64
#  6   arrival_date_day_of_month       217 non-null    int64
#  7   stays_in_weekend_nights         217 non-null    int64
#  8   stays_in_week_nights            217 non-null    int64
#  9   adults                          217 non-null    int64
#  10  children                        217 non-null    float64
#  11  babies                          217 non-null    int64
# ...

# %%
var.dropna(thresh=1)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
var.fillna("python")
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
var.fillna({"is_canceled": "python"})
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
var.fillna(method="ffill",axis=0)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15524\3328252635.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   var.fillna(method="ffill",axis=0)
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# ...

# %%
var.fillna(0,inplace=True)
var
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...

# %%
var.fillna("python",limit = 2)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2392    Resort Hotel            0          6               2015
# 2697    Resort Hotel            0         24               2015
# 2867    Resort Hotel            0         24               2015
# 2877    Resort Hotel            0         24               2015
# 2878    Resort Hotel            0         24               2015
# ...              ...          ...        ...                ...
# 112499    City Hotel            0         13               2017
# 113046    City Hotel            0         13               2017
# 113082    City Hotel            0         13               2017
# 113627    City Hotel            0        210               2017
# 116451    City Hotel            0        191               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 2392              October                        42
# 2697              October                        44
# ...
