# %%
import pandas as pd

var = pd.read_csv(r"D:\hotel_bookings.csv")
var
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
var.replace(to_replace=0,value=12)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel           12        342               2015
# 1       Resort Hotel           12        737               2015
# 2       Resort Hotel           12          7               2015
# 3       Resort Hotel           12         13               2015
# 4       Resort Hotel           12         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel           12         23               2017
# 119386    City Hotel           12        102               2017
# 119387    City Hotel           12         34               2017
# 119388    City Hotel           12        109               2017
# 119389    City Hotel           12        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
var.replace("[A-za-z]","python",regex=True)
# Out:
#                                                     hotel  is_canceled  \
# 0       pythonpythonpythonpythonpythonpython pythonpyt...            0
# 1       pythonpythonpythonpythonpythonpython pythonpyt...            0
# 2       pythonpythonpythonpythonpythonpython pythonpyt...            0
# 3       pythonpythonpythonpythonpythonpython pythonpyt...            0
# 4       pythonpythonpythonpythonpythonpython pythonpyt...            0
# ...                                                   ...          ...
# 119385  pythonpythonpythonpython pythonpythonpythonpyt...            0
# 119386  pythonpythonpythonpython pythonpythonpythonpyt...            0
# 119387  pythonpythonpythonpython pythonpythonpythonpyt...            0
# 119388  pythonpythonpythonpython pythonpythonpythonpyt...            0
# 119389  pythonpythonpythonpython pythonpythonpythonpyt...            0
#
#         lead_time  arrival_date_year                    arrival_date_month  \
# ...

# %%
var
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
var.replace({"is_canceled":'[A-z]'},22,regex=True)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
var.replace(1,method="ffill",limit=3,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4596\2766965574.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   var.replace(1,method="ffill",limit=3,inplace=True)
